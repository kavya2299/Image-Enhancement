# %% [markdown]
# <a href="https://colab.research.google.com/github/kavya2299/Image-Enhancement/blob/main/Standard_UNET_aug_sweep_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Description
#
# * This notebook gives a detailed understanding of the techniques used to enhance the ultrasound images in both a qualitative and quantitative manner
# * Dataset: The data is divided into a training set of 999 images and a test set of 335 images. The size of each 2D ultrasound image is 800 by 540 pixels with a pixel size ranging from 0.052 to 0.326 mm.

# %% [markdown]
# # HFLIP, ROTATION AND LINEAR SHIFT

# %% [markdown]
# ## Import Packages

# %%
## these are basic system packages to access directories and files
import os
import time

## these are packages that we need to use to visualize the dataset 
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd

## to make data augmentations
from torchvision.transforms import ToPILImage
from PIL import Image
import imutils
import cv2

## these are basic python packages
import math
import random
import csv

## these are packages that are a part of Pytorch, the deep-learning library
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import datasets, models, transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

## these are a few metrics used to make quantitative comparisons
from skimage.measure import compare_ssim
##from tabulate import tabulate

# !pip install wandb
import wandb
wandb.login()
# Out:
# Collecting wandb
#   Downloading https://files.pythonhosted.org/packages/4b/85/ee3bec131a1078f0450140abc6c3f17177e832109c44912dca2a82e9f7d9/wandb-0.9.1-py2.py3-none-any.whl (1.4MB)
#      |████████████████████████████████| 1.4MB 3.4MB/s
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.13)
# Collecting configparser>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/4b/6b/01baa293090240cf0562cc5eccb69c6f5006282127f2b846fad011305c79/configparser-5.0.0-py3-none-any.whl
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.352.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (5.4.8)
# Collecting shortuuid>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/25/a6/2ecc1daa6a304e7f1b216f0896b26156b78e7c38e1211e9b798b4716c53d/shortuuid-1.0.1-py3-none-any.whl
# Collecting gql==0.2.0
#   Downloading https://files.pythonhosted.org/packages/c4/6f/cf9a3056045518f06184e804bae89390eb706168349daa9dff8ac609962a/gql-0.2.0.tar.gz
# Collecting docker-pycreds>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting subprocess32>=3.5.3
#   Downloading https://files.pythonhosted.org/packages/32/c8/564be4d12629b912ea431f1a50eb8b3b9d00f1a0b1ceff17f266be190007/subprocess32-3.5.4.tar.gz (97kB)
#      |████████████████████████████████| 102kB 6.5MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (1.12.0)
# Collecting sentry-sdk>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/1b/95/9a20eebcedab2c1c63fad59fe19a0469edfc2a25b8576497e8084629c2ff/sentry_sdk-0.14.4-py2.py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 16.4MB/s
# Collecting GitPython>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/8c/f9/c315aa88e51fabdc08e91b333cfefb255aff04a2ee96d632c32cb19180c9/GitPython-3.1.3-py3-none-any.whl (451kB)
#      |████████████████████████████████| 460kB 13.8MB/s
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.23.0)
# Collecting watchdog>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/73/c3/ed6d992006837e011baca89476a4bbffb0a91602432f73bd4473816c76e2/watchdog-0.10.2.tar.gz (95kB)
#      |████████████████████████████████| 102kB 8.6MB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.8.1)
# Collecting graphql-core<2,>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/b0/89/00ad5e07524d8c523b14d70c685e0299a8b0de6d0727e368c41b89b7ed0b/graphql-core-1.1.tar.gz (70kB)
#      |████████████████████████████████| 71kB 5.0MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.6/dist-packages (from gql==0.2.0->wandb) (2.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from sentry-sdk>=0.4.0->wandb) (2020.4.5.1)
# Requirement already satisfied: urllib3>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from sentry-sdk>=0.4.0->wandb) (1.24.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 7.2MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (3.0.4)
# Collecting pathtools>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/e7/7f/470d6fcdf23f9f3518f6b0b76be9df16dcc8630ad409947f8be2eb0ed13a/pathtools-0.1.2.tar.gz
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Building wheels for collected packages: gql, subprocess32, watchdog, graphql-core, pathtools
#   Building wheel for gql (setup.py) ... done
#   Created wheel for gql: filename=gql-0.2.0-cp36-none-any.whl size=7630 sha256=6710b55afae4dd8ce4e4190d4a80da14043d3a06414ca522261aabf2e0b4ce4d
#   Stored in directory: /root/.cache/pip/wheels/ce/0e/7b/58a8a5268655b3ad74feef5aa97946f0addafb3cbb6bd2da23
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp36-none-any.whl size=6489 sha256=e7fba736ba58ea938b77091b9684939605840b8ed8c1eb3b69db03e7cad0b778
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
#   Building wheel for watchdog (setup.py) ... done
#   Created wheel for watchdog: filename=watchdog-0.10.2-cp36-none-any.whl size=73605 sha256=64effb0a5aa965044d99377f1bb352b1f8cbe3fb335adabecee0c16cce2c180d
#   Stored in directory: /root/.cache/pip/wheels/bc/ed/6c/028dea90d31b359cd2a7c8b0da4db80e41d24a59614154072e
#   Building wheel for graphql-core (setup.py) ... done
#   Created wheel for graphql-core: filename=graphql_core-1.1-cp36-none-any.whl size=104650 sha256=986718c528a9c6a55bec4a2ff075027eff11d3d5d62d803f856b78f564da2403
#   Stored in directory: /root/.cache/pip/wheels/45/99/d7/c424029bb0fe910c63b68dbf2aa20d3283d023042521bcd7d5
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-cp36-none-any.whl size=8784 sha256=b8cb13b2fb818dff6dc9745bd5aaeb97eb83c9261a51ede6d189df71e72e37ad
#   Stored in directory: /root/.cache/pip/wheels/0b/04/79/c3b0c3a0266a3cb4376da31e5bfe8bba0c489246968a68e843
# Successfully built gql subprocess32 watchdog graphql-core pathtools
# Installing collected packages: configparser, shortuuid, graphql-core, gql, docker-pycreds, subprocess32, sentry-sdk, smmap, gitdb, GitPython, pathtools, watchdog, wandb
# Successfully installed GitPython-3.1.3 configparser-5.0.0 docker-pycreds-0.4.0 gitdb-4.0.5 gql-0.2.0 graphql-core-1.1 pathtools-0.1.2 sentry-sdk-0.14.4 shortuuid-1.0.1 smmap-3.0.4 subprocess32-3.5.4 wandb-0.9.1 watchdog-0.10.2
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# ## Defining the augment() function

# %%
# x is an image 
mean = 0
sigma = 1

def augment(x):
    
    """
    We add the speckle noise(multiplicative gaussian noise) because it is usually present in any practical image. 
    Further, we make all sorts of augmentations to make the model robust. The augmentations imclude gamma 
    correction, rotation, horizontal flip, linear shifts. Then, a few others to adjust the non-linear intensity 
    inhomogeneity in the images and to account for shadow regions on the images by adding occulded patches.
    """
    # copy the image into 2 variables, one for the noisy image and the other for a clean image

    noisy_x = np.copy(x)
    clean_x = np.copy(x)
    
    # Add Speckle Noise   
    shape = noisy_x.shape[:2]
    intensity_noise = np.random.uniform(low=0.2, high=0.5)
    noisy_x = noisy_x*(1 + intensity_noise*np.random.normal(mean, sigma, size=shape[0]*shape[1]).reshape(shape[0],shape[1]).astype('float32'))

    # ROTATION
    angle = np.random.uniform(low=-10,high=10)
    noisy_x = imutils.rotate(noisy_x, angle) # cw for rotating the image in the clockwise direction, input a negative value  
    noisy_x = np.array(noisy_x)     
    clean_x = imutils.rotate(clean_x, angle) # cw for rotating the image in the clockwise direction, input a negative value  
    clean_x = np.array(clean_x)

    # HORIZONTAL FLIP
    if random.randint(0,1)==0:
        noisy_x = np.fliplr(noisy_x)
        clean_x = np.fliplr(clean_x)
    else:
        noisy_x = noisy_x
        clean_x = clean_x 
    
    #SHIFT
    hor = noisy_x.shape[0]
    vert = noisy_x.shape[1]
    percent = random.uniform(0,0.05)
    translate = np.float32([[1,0,percent*hor],[0,1,percent*vert]])

    noisy_x = cv2.warpAffine(noisy_x,translate,(noisy_x.shape[1],noisy_x.shape[0]))
    clean_x = cv2.warpAffine(clean_x,translate,(clean_x.shape[1],clean_x.shape[0]))

    
    #Resize the image to half its size
    dim = (400,270)
 
    noisy_x = cv2.resize(noisy_x, dim, interpolation = cv2.INTER_AREA)
    noisy_x=noisy_x[:256, :384]
    clean_x = cv2.resize(clean_x, dim, interpolation = cv2.INTER_AREA)
    clean_x=clean_x[:256, :384]
    
    #finally taking the norm in order to normalize the images
    norm_noisy = np.linalg.norm(noisy_x)
    norm_clean = np.linalg.norm(clean_x)

    noisy_x = noisy_x/norm_noisy
    clean_x = clean_x/norm_clean
    
    return clean_x,noisy_x

# %%
def noise(x):
    noisy_x = np.copy(x)
    clean_x = np.copy(x)
    
    # Add Speckle Noise   
    shape = noisy_x.shape[:2]
    intensity_noise = np.random.uniform(low=0.2, high=0.5)
    noisy_x = noisy_x*(1 + intensity_noise*np.random.normal(mean, sigma, size=shape[0]*shape[1]).reshape(shape[0],shape[1]).astype('float32'))
    
    dim = (400,270)
 
    noisy_x = cv2.resize(noisy_x, dim, interpolation = cv2.INTER_AREA)
    noisy_x=noisy_x[:256, :384]
    clean_x = cv2.resize(clean_x, dim, interpolation = cv2.INTER_AREA)
    clean_x=clean_x[:256, :384]
    
    #finally taking the norm in order to normalize the images
    norm_noisy = np.linalg.norm(noisy_x)
    norm_clean = np.linalg.norm(clean_x)

    noisy_x = noisy_x/norm_noisy
    clean_x = clean_x/norm_clean

    noisy_x = noisy_x/norm_noisy
    return clean_x, noisy_x

# %% [markdown]
# ## Data loaders

# %%
"""
The train dataset generator is used to gather the unzipped files and sort them for easy access during training. 
"""

class train_dataset_generator(Dataset):
    def __init__(self,root_dir):
        self.image_filenames = []
        for filename in os.listdir(root_dir):
            if filename.endswith('HC.png'):
                self.image_filenames.append(os.path.join(root_dir,filename))
                self.image_filenames.sort()
                
        self.transforms = transforms.Compose([                  
                          transforms.ToTensor()]) # the mean and variance can be obtained from the cell below
        
    def __len__(self):
        return len(self.image_filenames)

    def get_basename(self,index):
        print (os.path.basename(self.image_filenames[index])) 

    def show(self,index):
        image = (cv2.imread(self.image_filenames[index],0))
        plt.imshow(image,cmap='gray')

    def __getitem__(self,index):
        image_orig = cv2.imread(self.image_filenames[index],0)
        image = np.copy(image_orig)
        image_orig,image = augment(image)
        image_orig,image = np.float32(image_orig),np.float32(image)
        image_orig,image = self.transforms(image_orig),self.transforms(image)
        
        #self.images = transforms.ToTensor(np.asarray([image, rotate(image), gaussian_noise(image), speckle_noise(image), hflip(image), non_linear_intensity(image)]))
        return image_orig,image
    

"""
The test dataset generator is used to gather the unzipped files and sort themfor easy access. 
"""

class test_dataset_generator(Dataset):
    def __init__(self,root_dir):
        self.image_filenames = []
        for filename in os.listdir(root_dir):
            if filename.endswith('.png'):
                self.image_filenames.append(os.path.join(root_dir,filename))
                self.image_filenames.sort()
        self.transforms = transforms.Compose([
                          transforms.ToTensor()])#,
                         # transforms.Normalize((0,),(1,))])#mean,variance
        
    def __len__(self):
        return len(self.image_filenames)

    def get_basename(self,index):
        print (os.path.basename(self.image_filenames[index])) 

    def show(self,index):
        image = (cv2.imread(self.image_filenames[index],0))
        plt.imshow(image,cmap='gray')

    def __getitem__(self,index):
        image_orig = cv2.imread(self.image_filenames[index],0)
        image = np.copy(image_orig)
        image_orig,image = noise(image)
        image_orig,image = np.float32(image_orig),np.float32(image)
        image_orig,image = self.transforms(image_orig),self.transforms(image)
        
        #self.images = transforms.ToTensor(np.asarray([image, rotate(image), gaussian_noise(image), speckle_noise(image), hflip(image), non_linear_intensity(image)]))
        return image_orig,image

# %% [markdown]
# ### Load the dataset into the data loaders

# %%
"""
Load the paths into the data generators to load into the data loaders. 
Create a split of 90:10 train:validation.
Declare the batch size in accordance with the amount of GPU used 
"""
# generate the data for both train and test
# modify the path according to your need
train_dataset = train_dataset_generator('/content/drive/My Drive/Dataset/training_set')
test_dataset = test_dataset_generator('/content/drive/My Drive/Dataset/Test_11')

len_valid_set = int(0.1*len(train_dataset))
len_train_set = len(train_dataset) - len_valid_set

print("The length of Train set is {}".format(len_train_set))
print("The length of Valid set is {}".format(len_valid_set))
print("The length of Test set is {}".format(len(test_dataset)))

# vary the batch size as and when needed
batch_size = 2

# split the dataset into train and validation datasets
train_dataset , valid_dataset = torch.utils.data.random_split(train_dataset, [len_train_set, len_valid_set])

# shuffle and batch the datasets
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1,shuffle=False)
# Out:
# The length of Train set is 900
# The length of Valid set is 99
# The length of Test set is 11

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Sanity check of the data from the dataloader

# %%
"""
This cell is to visualize how the corresponding original image is made noisier 
with the help of the augment function
"""
image = next(iter(train_loader))
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(image[0][0].squeeze(0),cmap='gray')
plt.subplot(122)
plt.imshow(image[1][0].squeeze(0),cmap='gray')

# %% [markdown]
# ## Architecture

# %%
## define the NN architecture
import torch
#from torchsummary import summary
import torch.nn as nn

class ConvDenoiser(nn.Module):

    """
    this is the network that is used for the image enhancement task 
    """
    def __init__(self, activation):
        super(ConvDenoiser, self).__init__()
        ## downsampling blocks with ELU activations
        self.conv1 = nn.Sequential(
                      nn.Conv2d(1,64,3,padding=1),
                      nn.ELU(),
                      nn.Conv2d(64,64,3,padding=1),
                      nn.ELU())
        self.conv2 = nn.Sequential(
                      nn.Conv2d(64,128,3,padding=1),
                      nn.ELU(),
                      nn.Conv2d(128,128,3,padding=1),
                      nn.ELU())
        self.conv3 = nn.Sequential(
                      nn.Conv2d(128,256,3,padding=1),
                      nn.ELU(),
                      nn.Conv2d(256,256,3,padding=1),
                      nn.ELU())
        self.conv4 = nn.Sequential(
                      nn.Conv2d(256,512,3,padding=1),
                      nn.ELU(),
                      nn.Conv2d(512,512,3,padding=1),
                      nn.ELU())
        
        ## bottleneck/latent space
        self.bottleneck = nn.Sequential(
                          nn.Conv2d(512,1024,3,padding=1),
                          nn.ELU(),
                          nn.Conv2d(1024,1024,3,padding=1),
                          nn.ELU())
        
        ## transposed convolutional layer
        self.t_conv4 = nn.ConvTranspose2d(1024,512,2,stride=2)
        self.t_conv3 = nn.ConvTranspose2d(512,256,2,stride=2)
        self.t_conv2 = nn.ConvTranspose2d(256,128,2,stride=2)
        self.t_conv1 = nn.ConvTranspose2d(128,64,2,stride=2)

        ## maxpooling layer
        self.pool = nn.MaxPool2d(2,2)

        ## upsampling blocks with ELU activations
        self.upconv4 = nn.Sequential(
                        nn.Conv2d(1024,512,3,padding=1),
                        nn.ELU(),
                        nn.Conv2d(512,512,3,padding=1),
                        nn.ELU())
        self.upconv3 = nn.Sequential(
                        nn.Conv2d(512,256,3,padding=1),
                        nn.ELU(),
                        nn.Conv2d(256,256,3,padding=1),
                        nn.ELU())
        self.upconv2 = nn.Sequential(
                        nn.Conv2d(256,128,3,padding=1),
                        nn.ELU(),
                        nn.Conv2d(128,128,3,padding=1),
                        nn.ELU())
        self.upconv1 = nn.Sequential(
                        nn.Conv2d(128,64,3,padding=1),
                        nn.ELU(),
                        nn.Conv2d(64,64,3,padding=1),
                        nn.ELU())
        
        ## output function
        self.activation = nn.Sequential(
                        nn.Conv2d(64, 1, 3, padding=1),
                        activation)
         
    def forward(self, x):
        ## encoding blocks

        conv1 = self.conv1(x)
        pool1 = self.pool(conv1)
        conv2 = self.conv2(pool1)
        pool2 = self.pool(conv2)
        conv3 = self.conv3(pool2)
        pool3 = self.pool(conv3)    
        conv4 = self.conv4(pool3)
        pool4 = self.pool(conv4)
        
        ## bottleneck
        bottleneck = self.bottleneck(pool4)

        ## decoding blocks

        t_conv4 = self.t_conv4(bottleneck)
        concat4 = torch.cat((conv4,t_conv4),1)
        upconv4 = self.upconv4(concat4)

        t_conv3 = self.t_conv3(upconv4)
        concat3 = torch.cat((conv3,t_conv3),1)
        upconv3 = self.upconv3(concat3)

        t_conv2 = self.t_conv2(upconv3)
        concat2 = torch.cat((conv2,t_conv2),1)
        upconv2 = self.upconv2(concat2)

        t_conv1 = self.t_conv1(upconv2)
        concat1 = torch.cat((conv1,t_conv1),1)
        upconv1 = self.upconv1(concat1)

        ## output function
        out = self.activation(upconv1)
        return out
## instantiate an object of the class and move the network to the GPU if available
## to use a best network variable for storing the best state of the model over the epochs

# %% [markdown]
# ## Training

# %%
def get_correct(output,input):
    ## to get the number of images that closely match their inputs
    return output.eq(input).sum().item()

# %%
def train(network, optimizer, criterion):

    """
    This function is used to train the network by adding a random noise to the images. The loss function used is RMSE and the optimizer 
    are defined below. 
    
    There exists a noise factor to define the amount of noise added to the baseline images. Input a noise factor to train the network given 
    that amount of noise. Once the noise is added, we move both the noisy images and the original baseline images to the GPU and then we 
    process the outputs over the network and obtain the predictions. 
    
    The outputs must be such that they must closely resemble the baseline images (without noise) and remove the innate noise in the baseline.
    The loss computed is given by the train_loss.

    """

    # monitor training loss
    train_loss = 0.0

    # monitor training accuracy
    train_accuracy = 0.0
    total_correct = 0
    
    # load data and generate both noisy and clean counterparts
    train_dataset = train_dataset_generator('/content/drive/My Drive/Dataset/training_set')
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,shuffle=True)
    #print("data loaded for "+ str(epoch+1))
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    network.to(device)
    network.train()    

    for data in train_loader:
        # assigning the original images 
        images = data[0][:] 
        images = images.float()

        # assigning the noisy images 
        noisy_imgs = data[1][:]

        # move the noisy images and the input images to gpu for computation
        noisy_imgs = noisy_imgs.to(device)
        images = images.to(device)

        # clear the gradients of all optimized variables to ensure they are all initialized to 0
        optimizer.zero_grad()

        # forward pass: compute predicted outputs by passing *noisy* images to the model
        outputs = network(noisy_imgs)

        # calculate the RMSE loss
        # the "target" is still the original, clean images
        loss = torch.sqrt(criterion(outputs, images))

        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()

        # perform a single optimization step (parameter update)
        # here it will be for a specific batch of data
        optimizer.step()

        # update running training loss
        train_loss += loss.item()

        # get the accuracy on the training dataset by accumulating the number of correct items
        total_correct += get_correct(outputs,images)
        
    # get the average training statistics for every epoch
    train_loss = train_loss/len(train_loader)
    train_accuracy = total_correct/len(train_loader)

    return train_loss, train_accuracy

def validate(network, optimizer, criterion):
  
    """
    This function is used to validate the network by adding a random noise to the images. The loss function used is RMSE and the optimizer 
    are defined below. 
    
    Once the noise is added, we move both the noisy images and the original baseline images to the GPU and then we 
    process the outputs over the network and obtain the predictions. 
    
    The outputs must be such that they must closely resemble the baseline images (without noise) and remove the innate noise in the baseline.
    The loss computed is given by the train_loss.

    """
    # monitor the validation loss and accuracy
    val_loss = 0.0
    val_accuracy = 0.0
    val_correct = 0
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    network = network.to(device)
    network.eval()
    
    for data in valid_loader:
        # assigning the original images 
        images = data[0][:]

        # assigning the noisy images 
        noisy_images = data[1][:]

        # move the input images and the noisy images to the gpu 
        noisy_images = noisy_images.to(device)
        images = images.to(device)

        # get the predictions from the network 
        output = network(noisy_images)

        # get the validation losses
        valid_loss = torch.sqrt(criterion(output, images.float()))
        val_loss += valid_loss.item()    

        # get the validation accuracy
        val_correct += get_correct(output,images)

    # get the average validation statistics 
    val_loss = val_loss/len(valid_loader)
    val_accuracy = val_correct/len(valid_loader)
    return val_loss, val_accuracy

# %%
class sweep_function():
    def __init__(self, activation, optimizer, train, validate, criterion, log_dict):
        self.optimizer = optimizer
        self.train = train
        self.validate = validate
        self.criterion = criterion
        self.log_dict = log_dict
        self.activation = activation
        

    def __call__(self):
        print("sweep under process")

        wandb.init(project=self.log_dict['project'])

        network = ConvDenoiser(activation=self.activation[wandb.config.activation]) 
        best_network = ConvDenoiser(activation=self.activation[wandb.config.activation])
        
        criterion = self.criterion[wandb.config.criterion]
        optimizer = self.optimizer[wandb.config.optimizer](network.parameters(),0.001)

        best_loss = 0.0
        
        path = str(wandb.config.criterion)+str(wandb.config.optimizer)+str(wandb.config.activation)
        
        for epoch in range(0, wandb.config.epochs):    
    
            train_loss, train_accuracy = self.train(network, optimizer, criterion)
            
            val_loss, val_accuracy = self.validate(network, optimizer, criterion)

            if epoch == 0:
                best_loss = val_loss
                best_network = network
                print("best model saved for ",str(epoch+1))
                torch.save(best_network.state_dict(), '/home/beagle/Dropbox/IMAGE ENHANCEMENT/KAVYA/Best models/'+path+'.pth')
            

            elif epoch > 0 and val_loss < best_loss:
                best_loss = val_loss
                best_network = network
                print("best model saved for ",str(epoch+1))
                torch.save(best_network.state_dict(), '/home/beagle/Dropbox/IMAGE ENHANCEMENT/KAVYA/Best models/'+path+'.pth')
            

            # save the best model every epoch so as to be able to resume from where it was left to train
            # the path should be mentioned as .pth   

            #torch.save(model.state_dict(), '/home/beagle/Dropbox/IMAGE ENHANCEMENT/KAVYA/Best models/S-UNET_no_augment.pth')
            print('Epoch: {} \tTraining Loss: {:.4f} \tValidation Loss: {:.4f} \tTrain Accuracy: {:.2f} \tValidation Accuracy: {:.2f} '.format(epoch+1,train_loss,val_loss,train_accuracy,val_accuracy))
            wandb.log({'training_loss': train_loss,
                        'validation_loss': val_loss,
                        'training_accuracy': train_accuracy,
                        'validation_accuracy': val_accuracy})

# %%
def generate_sweep_config(criterion, epochs, optimizer, activation, metric=None, goal=None):
    
    if goal != 'maximize' and goal != 'minimize' and goal is not None:
        raise AssertionError("goal must be 'maximize' , 'minimize' or None")

    sweep_config = {
        'method': 'grid',

        'metric': {
        'name': metric,
        'goal': goal,   
        },

        'parameters': {
            'epochs':{
                'values': epochs
            },
            
            'criterion': {
                'values': list(criterion.keys())
            },
            'optimizer': {
                'values': list(optimizer.keys())
            },
            'activation': {
                'values': list(activation.keys())
            }
        }
    }
    return sweep_config

# %%
def sweep(epochs, criterion, optimizer, activation, metric=None, goal=None, log_dict=None):
    
    sweep_config = generate_sweep_config(criterion=criterion,
                                         epochs = epochs,
                                        optimizer=optimizer,
                                         activation=activation,
                                          metric=metric,
                                          goal=goal)
    
    sweep_func = sweep_function(optimizer = optimizer,
                                    train = train,
                                    validate = validate,
                                    activation = activation,
                                    criterion = criterion,
                                    log_dict = log_dict)
    
    # Run the sweep
    wandb.agent(wandb.sweep(sweep_config), function=sweep_func)

# %%
activation = {
    'tanh': nn.Tanh(),
    'sigmoid': nn.Sigmoid(),
    'ELU': nn.ELU(),
    'ReLU': nn.ReLU()
}
criterion = {
    'MSE': nn.MSELoss()
}

optimizer = {
    'Adam': optim.Adam,
    'SGD': optim.SGD
}

epochs = [120]

log_dict = {
    'project': 'sweep'
}

sweep(epochs = epochs,
     criterion=criterion,
     optimizer=optimizer,
      activation=activation,
     metric='validation_loss',
     goal='minimize',
     log_dict=log_dict)
# Out:
# Create sweep with ID: izhsj4p8
# Sweep URL: https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8
# wandb: Agent Starting Run: dgemlm5u with config:
# 	activation: tanh
# 	criterion: MSE
# 	epochs: 120
# 	optimizer: Adam
# wandb: Agent Started Run: dgemlm5u
# sweep under process
# wandb: WARNING Ignoring project='sweep' passed to wandb.init when running a sweep
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/image_enhancement/uncategorized" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized</a><br/>
#                 Sweep page: <a href="https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8</a><br/>
# Run page: <a href="https://app.wandb.ai/image_enhancement/uncategorized/runs/dgemlm5u" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized/runs/dgemlm5u</a><br/>
# wandb: Wandb version 0.9.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# best model saved for  1
# Epoch: 1 	Training Loss: 0.0179 	Validation Loss: 0.0020 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# best model saved for  2
# Epoch: 2 	Training Loss: 0.0019 	Validation Loss: 0.0003 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# best model saved for  3
# Epoch: 3 	Training Loss: 0.0003 	Validation Loss: 0.0002 	Train Accuracy: 0.04 	Validation Accuracy: 0.04
# Epoch: 4 	Training Loss: 0.0003 	Validation Loss: 0.0002 	Train Accuracy: 0.05 	Validation Accuracy: 0.08
# Epoch: 5 	Training Loss: 0.0003 	Validation Loss: 0.0004 	Train Accuracy: 0.04 	Validation Accuracy: 0.06
# Epoch: 6 	Training Loss: 0.0004 	Validation Loss: 0.0003 	Train Accuracy: 0.04 	Validation Accuracy: 0.06
# Epoch: 7 	Training Loss: 0.0005 	Validation Loss: 0.0003 	Train Accuracy: 0.04 	Validation Accuracy: 0.04
# Epoch: 8 	Training Loss: 0.0004 	Validation Loss: 0.0003 	Train Accuracy: 0.29 	Validation Accuracy: 0.04
# Epoch: 9 	Training Loss: 0.0003 	Validation Loss: 0.0003 	Train Accuracy: 0.08 	Validation Accuracy: 0.06
# Epoch: 10 	Training Loss: 0.0003 	Validation Loss: 0.0003 	Train Accuracy: 0.06 	Validation Accuracy: 0.04
# Epoch: 11 	Training Loss: 0.1061 	Validation Loss: 1.0000 	Train Accuracy: 0.05 	Validation Accuracy: 0.00
# Epoch: 12 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 13 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 14 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 15 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 16 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 17 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 18 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 19 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 20 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 21 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 22 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 23 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 24 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 25 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 26 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 27 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 28 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 29 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 30 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 31 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 32 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 33 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 34 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 35 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 36 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 37 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 38 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 39 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 40 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 41 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 42 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 43 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 44 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 45 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 46 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 47 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 48 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 49 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 50 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 51 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 52 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 53 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 54 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 55 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 56 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 57 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 58 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 59 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 60 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 61 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 62 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 63 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 64 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 65 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 66 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 67 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 68 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 69 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 70 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 71 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 72 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 73 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 74 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 75 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 76 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 77 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 78 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 79 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 80 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 81 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 82 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 83 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 84 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 85 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 86 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 87 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 88 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 89 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 90 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 91 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 92 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 93 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 94 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 95 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 96 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 97 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 98 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 99 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 100 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 101 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 102 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 103 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 104 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 105 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 106 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 107 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 108 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 109 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 110 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 111 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 112 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 113 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 114 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 115 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 116 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 117 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 118 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 119 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 120 	Training Loss: 1.0000 	Validation Loss: 1.0000 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# wandb: Agent Finished Run: dgemlm5u
#
# wandb: Agent Starting Run: rekn9m4u with config:
# 	activation: tanh
# 	criterion: MSE
# 	epochs: 120
# 	optimizer: SGD
# wandb: Agent Started Run: rekn9m4u
# sweep under process
# wandb: WARNING Ignoring project='sweep' passed to wandb.init when running a sweep
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/image_enhancement/uncategorized" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized</a><br/>
#                 Sweep page: <a href="https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8</a><br/>
# Run page: <a href="https://app.wandb.ai/image_enhancement/uncategorized/runs/rekn9m4u" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized/runs/rekn9m4u</a><br/>
# wandb: Wandb version 0.9.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# best model saved for  1
# Epoch: 1 	Training Loss: 0.0028 	Validation Loss: 0.0026 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 2 	Training Loss: 0.0025 	Validation Loss: 0.0026 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  3
# Epoch: 3 	Training Loss: 0.0024 	Validation Loss: 0.0025 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# best model saved for  4
# Epoch: 4 	Training Loss: 0.0024 	Validation Loss: 0.0024 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 5 	Training Loss: 0.0024 	Validation Loss: 0.0024 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# best model saved for  6
# Epoch: 6 	Training Loss: 0.0023 	Validation Loss: 0.0022 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 7 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 8 	Training Loss: 0.0023 	Validation Loss: 0.0024 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# best model saved for  9
# Epoch: 9 	Training Loss: 0.0023 	Validation Loss: 0.0021 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 10 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 11 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 12 	Training Loss: 0.0023 	Validation Loss: 0.0025 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 13 	Training Loss: 0.0023 	Validation Loss: 0.0024 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# best model saved for  14
# Epoch: 14 	Training Loss: 0.0023 	Validation Loss: 0.0020 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 15 	Training Loss: 0.0023 	Validation Loss: 0.0022 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 16 	Training Loss: 0.0023 	Validation Loss: 0.0024 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 17 	Training Loss: 0.0023 	Validation Loss: 0.0022 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 18 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 19 	Training Loss: 0.0023 	Validation Loss: 0.0022 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 20 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 21 	Training Loss: 0.0022 	Validation Loss: 0.0023 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 22 	Training Loss: 0.0023 	Validation Loss: 0.0022 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 23 	Training Loss: 0.0022 	Validation Loss: 0.0022 	Train Accuracy: 0.03 	Validation Accuracy: 0.00
# best model saved for  24
# Epoch: 24 	Training Loss: 0.0022 	Validation Loss: 0.0020 	Train Accuracy: 0.03 	Validation Accuracy: 0.02
# Epoch: 25 	Training Loss: 0.0022 	Validation Loss: 0.0021 	Train Accuracy: 0.05 	Validation Accuracy: 0.00
# Epoch: 26 	Training Loss: 0.0022 	Validation Loss: 0.0025 	Train Accuracy: 0.05 	Validation Accuracy: 0.02
# Epoch: 27 	Training Loss: 0.0022 	Validation Loss: 0.0021 	Train Accuracy: 0.05 	Validation Accuracy: 0.00
# Epoch: 28 	Training Loss: 0.0022 	Validation Loss: 0.0022 	Train Accuracy: 0.02 	Validation Accuracy: 0.00
# Epoch: 29 	Training Loss: 0.0022 	Validation Loss: 0.0025 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 30 	Training Loss: 0.0022 	Validation Loss: 0.0023 	Train Accuracy: 0.00 	Validation Accuracy: 0.04
# Epoch: 31 	Training Loss: 0.0022 	Validation Loss: 0.0020 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 32 	Training Loss: 0.0022 	Validation Loss: 0.0021 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 33 	Training Loss: 0.0022 	Validation Loss: 0.0024 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 34 	Training Loss: 0.0022 	Validation Loss: 0.0021 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 35 	Training Loss: 0.0022 	Validation Loss: 0.0021 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  36
# Epoch: 36 	Training Loss: 0.0021 	Validation Loss: 0.0020 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 37 	Training Loss: 0.0021 	Validation Loss: 0.0021 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# best model saved for  38
# Epoch: 38 	Training Loss: 0.0021 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 39 	Training Loss: 0.0021 	Validation Loss: 0.0021 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# best model saved for  40
# Epoch: 40 	Training Loss: 0.0021 	Validation Loss: 0.0016 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 41 	Training Loss: 0.0021 	Validation Loss: 0.0018 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 42 	Training Loss: 0.0021 	Validation Loss: 0.0018 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 43 	Training Loss: 0.0021 	Validation Loss: 0.0022 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 44 	Training Loss: 0.0021 	Validation Loss: 0.0023 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 45 	Training Loss: 0.0020 	Validation Loss: 0.0018 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 46 	Training Loss: 0.0020 	Validation Loss: 0.0021 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 47 	Training Loss: 0.0020 	Validation Loss: 0.0016 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 48 	Training Loss: 0.0020 	Validation Loss: 0.0018 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 49 	Training Loss: 0.0020 	Validation Loss: 0.0020 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 50 	Training Loss: 0.0020 	Validation Loss: 0.0022 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 51 	Training Loss: 0.0020 	Validation Loss: 0.0016 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 52 	Training Loss: 0.0020 	Validation Loss: 0.0023 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 53 	Training Loss: 0.0020 	Validation Loss: 0.0022 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  54
# Epoch: 54 	Training Loss: 0.0020 	Validation Loss: 0.0015 	Train Accuracy: 0.00 	Validation Accuracy: 0.04
# Epoch: 55 	Training Loss: 0.0020 	Validation Loss: 0.0018 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 56 	Training Loss: 0.0019 	Validation Loss: 0.0022 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 57 	Training Loss: 0.0019 	Validation Loss: 0.0020 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 58 	Training Loss: 0.0019 	Validation Loss: 0.0022 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 59 	Training Loss: 0.0019 	Validation Loss: 0.0018 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 60 	Training Loss: 0.0019 	Validation Loss: 0.0022 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 61 	Training Loss: 0.0019 	Validation Loss: 0.0020 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 62 	Training Loss: 0.0019 	Validation Loss: 0.0019 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 63 	Training Loss: 0.0019 	Validation Loss: 0.0020 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 64 	Training Loss: 0.0019 	Validation Loss: 0.0020 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 65 	Training Loss: 0.0019 	Validation Loss: 0.0018 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 66 	Training Loss: 0.0019 	Validation Loss: 0.0019 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 67 	Training Loss: 0.0019 	Validation Loss: 0.0019 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 68 	Training Loss: 0.0018 	Validation Loss: 0.0018 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 69 	Training Loss: 0.0018 	Validation Loss: 0.0018 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 70 	Training Loss: 0.0018 	Validation Loss: 0.0019 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 71 	Training Loss: 0.0018 	Validation Loss: 0.0021 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 72 	Training Loss: 0.0018 	Validation Loss: 0.0019 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 73 	Training Loss: 0.0018 	Validation Loss: 0.0018 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 74 	Training Loss: 0.0018 	Validation Loss: 0.0017 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 75 	Training Loss: 0.0018 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 76 	Training Loss: 0.0018 	Validation Loss: 0.0018 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 77 	Training Loss: 0.0018 	Validation Loss: 0.0018 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 78 	Training Loss: 0.0018 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 79 	Training Loss: 0.0018 	Validation Loss: 0.0016 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 80 	Training Loss: 0.0018 	Validation Loss: 0.0019 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 81 	Training Loss: 0.0017 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 82 	Training Loss: 0.0017 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 83 	Training Loss: 0.0017 	Validation Loss: 0.0018 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 84 	Training Loss: 0.0017 	Validation Loss: 0.0018 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 85 	Training Loss: 0.0017 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 86 	Training Loss: 0.0017 	Validation Loss: 0.0018 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 87 	Training Loss: 0.0017 	Validation Loss: 0.0018 	Train Accuracy: 0.00 	Validation Accuracy: 0.04
# best model saved for  88
# Epoch: 88 	Training Loss: 0.0017 	Validation Loss: 0.0014 	Train Accuracy: 0.00 	Validation Accuracy: 0.04
# Epoch: 89 	Training Loss: 0.0017 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 90 	Training Loss: 0.0017 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 91 	Training Loss: 0.0017 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 92 	Training Loss: 0.0017 	Validation Loss: 0.0015 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 93 	Training Loss: 0.0017 	Validation Loss: 0.0015 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 94 	Training Loss: 0.0017 	Validation Loss: 0.0018 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 95 	Training Loss: 0.0017 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 96 	Training Loss: 0.0017 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 97 	Training Loss: 0.0016 	Validation Loss: 0.0015 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 98 	Training Loss: 0.0016 	Validation Loss: 0.0015 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 99 	Training Loss: 0.0016 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 100 	Training Loss: 0.0016 	Validation Loss: 0.0017 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 101 	Training Loss: 0.0016 	Validation Loss: 0.0016 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 102 	Training Loss: 0.0016 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 103 	Training Loss: 0.0016 	Validation Loss: 0.0016 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 104 	Training Loss: 0.0016 	Validation Loss: 0.0016 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 105 	Training Loss: 0.0016 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 106 	Training Loss: 0.0016 	Validation Loss: 0.0015 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 107 	Training Loss: 0.0016 	Validation Loss: 0.0016 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 108 	Training Loss: 0.0016 	Validation Loss: 0.0017 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 109 	Training Loss: 0.0016 	Validation Loss: 0.0016 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 110 	Training Loss: 0.0016 	Validation Loss: 0.0016 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 111 	Training Loss: 0.0016 	Validation Loss: 0.0015 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 112 	Training Loss: 0.0016 	Validation Loss: 0.0017 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 113 	Training Loss: 0.0016 	Validation Loss: 0.0015 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# Epoch: 114 	Training Loss: 0.0015 	Validation Loss: 0.0016 	Train Accuracy: 0.01 	Validation Accuracy: 0.02
# Epoch: 115 	Training Loss: 0.0015 	Validation Loss: 0.0016 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 116 	Training Loss: 0.0015 	Validation Loss: 0.0016 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 117 	Training Loss: 0.0015 	Validation Loss: 0.0016 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# Epoch: 118 	Training Loss: 0.0015 	Validation Loss: 0.0015 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# best model saved for  119
# Epoch: 119 	Training Loss: 0.0015 	Validation Loss: 0.0014 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# Epoch: 120 	Training Loss: 0.0015 	Validation Loss: 0.0016 	Train Accuracy: 0.00 	Validation Accuracy: 0.02
# wandb: Agent Finished Run: rekn9m4u
#
# wandb: Agent Starting Run: 81y0j4se with config:
# 	activation: sigmoid
# 	criterion: MSE
# 	epochs: 120
# 	optimizer: Adam
# wandb: Agent Started Run: 81y0j4se
# sweep under process
# wandb: WARNING Ignoring project='sweep' passed to wandb.init when running a sweep
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/image_enhancement/uncategorized" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized</a><br/>
#                 Sweep page: <a href="https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8</a><br/>
# Run page: <a href="https://app.wandb.ai/image_enhancement/uncategorized/runs/81y0j4se" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized/runs/81y0j4se</a><br/>
# wandb: Wandb version 0.9.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# best model saved for  1
# Epoch: 1 	Training Loss: 0.0053 	Validation Loss: 0.0032 	Train Accuracy: 42546.84 	Validation Accuracy: 44484.62
# Epoch: 2 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42852.79 	Validation Accuracy: 44507.20
# Epoch: 3 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42848.11 	Validation Accuracy: 43780.64
# best model saved for  4
# Epoch: 4 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42824.96 	Validation Accuracy: 43274.56
# Epoch: 5 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43150.15 	Validation Accuracy: 44045.12
# Epoch: 6 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42829.38 	Validation Accuracy: 43639.22
# Epoch: 7 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42882.53 	Validation Accuracy: 43966.82
# Epoch: 8 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42968.27 	Validation Accuracy: 44243.90
# Epoch: 9 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42950.18 	Validation Accuracy: 43625.88
# Epoch: 10 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43257.78 	Validation Accuracy: 43595.68
# Epoch: 11 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43001.52 	Validation Accuracy: 44106.24
# Epoch: 12 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43062.59 	Validation Accuracy: 44247.22
# Epoch: 13 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42818.10 	Validation Accuracy: 43199.44
# Epoch: 14 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42851.11 	Validation Accuracy: 43852.36
# Epoch: 15 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43097.77 	Validation Accuracy: 43630.26
# Epoch: 16 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43086.14 	Validation Accuracy: 44356.58
# Epoch: 17 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43343.63 	Validation Accuracy: 44109.00
# Epoch: 18 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42917.48 	Validation Accuracy: 43027.22
# Epoch: 19 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42822.44 	Validation Accuracy: 43186.60
# Epoch: 20 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43097.08 	Validation Accuracy: 44348.22
# Epoch: 21 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42895.95 	Validation Accuracy: 43611.24
# Epoch: 22 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42932.41 	Validation Accuracy: 44362.40
# Epoch: 23 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42811.46 	Validation Accuracy: 44395.26
# Epoch: 24 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43016.27 	Validation Accuracy: 43237.12
# Epoch: 25 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43059.89 	Validation Accuracy: 44041.50
# Epoch: 26 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43005.57 	Validation Accuracy: 44871.56
# Epoch: 27 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43226.33 	Validation Accuracy: 43899.52
# Epoch: 28 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43294.33 	Validation Accuracy: 44287.52
# Epoch: 29 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43331.08 	Validation Accuracy: 44249.44
# Epoch: 30 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43201.46 	Validation Accuracy: 43897.28
# Epoch: 31 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43178.86 	Validation Accuracy: 43658.30
# Epoch: 32 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42960.72 	Validation Accuracy: 43634.00
# Epoch: 33 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42951.99 	Validation Accuracy: 43921.22
# Epoch: 34 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42940.47 	Validation Accuracy: 43835.40
# Epoch: 35 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42864.99 	Validation Accuracy: 44464.54
# Epoch: 36 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43118.16 	Validation Accuracy: 43692.26
# Epoch: 37 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43223.32 	Validation Accuracy: 43553.06
# Epoch: 38 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43094.56 	Validation Accuracy: 44031.18
# Epoch: 39 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43000.99 	Validation Accuracy: 44224.62
# Epoch: 40 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42946.97 	Validation Accuracy: 43855.56
# Epoch: 41 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42894.99 	Validation Accuracy: 43195.92
# Epoch: 42 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43039.63 	Validation Accuracy: 44173.92
# Epoch: 43 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42770.89 	Validation Accuracy: 43769.96
# Epoch: 44 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42882.22 	Validation Accuracy: 44321.90
# Epoch: 45 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43029.85 	Validation Accuracy: 44012.84
# Epoch: 46 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42973.86 	Validation Accuracy: 43718.02
# Epoch: 47 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43056.40 	Validation Accuracy: 43666.34
# Epoch: 48 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43033.36 	Validation Accuracy: 43388.90
# Epoch: 49 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43032.03 	Validation Accuracy: 44242.50
# Epoch: 50 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43058.88 	Validation Accuracy: 44514.90
# Epoch: 51 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43011.18 	Validation Accuracy: 43498.94
# Epoch: 52 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43308.32 	Validation Accuracy: 43476.78
# Epoch: 53 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42925.18 	Validation Accuracy: 44007.64
# Epoch: 54 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43307.55 	Validation Accuracy: 43923.40
# Epoch: 55 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43419.35 	Validation Accuracy: 43933.08
# Epoch: 56 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42897.54 	Validation Accuracy: 43908.14
# Epoch: 57 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42800.65 	Validation Accuracy: 43971.60
# Epoch: 58 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42763.03 	Validation Accuracy: 43415.62
# Epoch: 59 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42922.27 	Validation Accuracy: 43793.56
# Epoch: 60 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43197.76 	Validation Accuracy: 44163.48
# Epoch: 61 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42969.49 	Validation Accuracy: 43804.80
# Epoch: 62 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42803.65 	Validation Accuracy: 43678.80
# Epoch: 63 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42998.74 	Validation Accuracy: 43235.90
# Epoch: 64 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43027.67 	Validation Accuracy: 44263.92
# Epoch: 65 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42955.39 	Validation Accuracy: 43582.46
# Epoch: 66 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43207.23 	Validation Accuracy: 44074.06
# Epoch: 67 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42973.80 	Validation Accuracy: 44377.74
# Epoch: 68 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42826.85 	Validation Accuracy: 44430.10
# Epoch: 69 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42853.84 	Validation Accuracy: 43359.70
# Epoch: 70 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43009.40 	Validation Accuracy: 43562.16
# Epoch: 71 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42929.03 	Validation Accuracy: 43013.86
# Epoch: 72 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43070.18 	Validation Accuracy: 43840.62
# Epoch: 73 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42996.52 	Validation Accuracy: 44253.00
# Epoch: 74 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43208.49 	Validation Accuracy: 43382.62
# Epoch: 75 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43222.81 	Validation Accuracy: 43936.90
# Epoch: 76 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43199.24 	Validation Accuracy: 44345.04
# Epoch: 77 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42660.04 	Validation Accuracy: 44211.40
# Epoch: 78 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42807.62 	Validation Accuracy: 44988.54
# Epoch: 79 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43096.93 	Validation Accuracy: 44151.48
# Epoch: 80 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43049.08 	Validation Accuracy: 44242.98
# Epoch: 81 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43246.22 	Validation Accuracy: 43562.24
# Epoch: 82 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42972.62 	Validation Accuracy: 43648.04
# Epoch: 83 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42821.32 	Validation Accuracy: 44724.46
# Epoch: 84 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43485.43 	Validation Accuracy: 44333.06
# Epoch: 85 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43263.71 	Validation Accuracy: 44399.62
# Epoch: 86 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43362.55 	Validation Accuracy: 43831.44
# Epoch: 87 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43310.99 	Validation Accuracy: 43989.04
# Epoch: 88 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43124.91 	Validation Accuracy: 45104.80
# Epoch: 89 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43087.95 	Validation Accuracy: 44256.08
# Epoch: 90 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43095.94 	Validation Accuracy: 43552.22
# Epoch: 91 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42970.06 	Validation Accuracy: 43312.46
# Epoch: 92 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43170.24 	Validation Accuracy: 43597.40
# Epoch: 93 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42929.97 	Validation Accuracy: 43755.56
# Epoch: 94 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43007.24 	Validation Accuracy: 44126.16
# Epoch: 95 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43180.08 	Validation Accuracy: 43638.28
# Epoch: 96 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43140.78 	Validation Accuracy: 44323.80
# Epoch: 97 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42975.56 	Validation Accuracy: 43881.32
# Epoch: 98 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42973.22 	Validation Accuracy: 44893.36
# Epoch: 99 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43019.56 	Validation Accuracy: 43891.28
# Epoch: 100 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43255.09 	Validation Accuracy: 43650.52
# Epoch: 101 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43271.62 	Validation Accuracy: 43649.08
# Epoch: 102 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43058.90 	Validation Accuracy: 44086.24
# Epoch: 103 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42978.87 	Validation Accuracy: 44061.56
# Epoch: 104 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43047.88 	Validation Accuracy: 43947.74
# Epoch: 105 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42963.64 	Validation Accuracy: 44815.00
# Epoch: 106 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43049.97 	Validation Accuracy: 44487.16
# Epoch: 107 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43102.38 	Validation Accuracy: 44794.44
# Epoch: 108 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42967.91 	Validation Accuracy: 43457.56
# Epoch: 109 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42787.22 	Validation Accuracy: 44378.42
# Epoch: 110 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43111.59 	Validation Accuracy: 44240.32
# Epoch: 111 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43340.53 	Validation Accuracy: 43101.92
# Epoch: 112 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43179.57 	Validation Accuracy: 43927.44
# Epoch: 113 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43126.21 	Validation Accuracy: 45319.64
# Epoch: 114 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43181.21 	Validation Accuracy: 43644.38
# Epoch: 115 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42969.48 	Validation Accuracy: 44466.98
# Epoch: 116 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42837.86 	Validation Accuracy: 43643.16
# Epoch: 117 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43246.73 	Validation Accuracy: 43689.62
# Epoch: 118 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42977.93 	Validation Accuracy: 44434.08
# Epoch: 119 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42992.78 	Validation Accuracy: 43701.84
# Epoch: 120 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43019.89 	Validation Accuracy: 44655.88
# wandb: Agent Finished Run: 81y0j4se
#
# wandb: Agent Starting Run: j2jkjasz with config:
# 	activation: sigmoid
# 	criterion: MSE
# 	epochs: 120
# 	optimizer: SGD
# wandb: Agent Started Run: j2jkjasz
# sweep under process
# wandb: WARNING Ignoring project='sweep' passed to wandb.init when running a sweep
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/image_enhancement/uncategorized" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized</a><br/>
#                 Sweep page: <a href="https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8</a><br/>
# Run page: <a href="https://app.wandb.ai/image_enhancement/uncategorized/runs/j2jkjasz" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized/runs/j2jkjasz</a><br/>
# wandb: Wandb version 0.9.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# best model saved for  1
# Epoch: 1 	Training Loss: 0.3792 	Validation Loss: 0.1311 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  2
# Epoch: 2 	Training Loss: 0.0368 	Validation Loss: 0.0124 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  3
# Epoch: 3 	Training Loss: 0.0092 	Validation Loss: 0.0073 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# best model saved for  4
# Epoch: 4 	Training Loss: 0.0064 	Validation Loss: 0.0057 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  5
# Epoch: 5 	Training Loss: 0.0053 	Validation Loss: 0.0050 	Train Accuracy: 0.01 	Validation Accuracy: 0.00
# best model saved for  6
# Epoch: 6 	Training Loss: 0.0047 	Validation Loss: 0.0045 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  7
# Epoch: 7 	Training Loss: 0.0043 	Validation Loss: 0.0042 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  8
# Epoch: 8 	Training Loss: 0.0041 	Validation Loss: 0.0040 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  9
# Epoch: 9 	Training Loss: 0.0039 	Validation Loss: 0.0039 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  10
# Epoch: 10 	Training Loss: 0.0038 	Validation Loss: 0.0038 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  11
# Epoch: 11 	Training Loss: 0.0037 	Validation Loss: 0.0037 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  12
# Epoch: 12 	Training Loss: 0.0037 	Validation Loss: 0.0036 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  13
# Epoch: 13 	Training Loss: 0.0036 	Validation Loss: 0.0036 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  14
# Epoch: 14 	Training Loss: 0.0036 	Validation Loss: 0.0035 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  15
# Epoch: 15 	Training Loss: 0.0035 	Validation Loss: 0.0035 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  16
# Epoch: 16 	Training Loss: 0.0035 	Validation Loss: 0.0035 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  17
# Epoch: 17 	Training Loss: 0.0035 	Validation Loss: 0.0035 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  18
# Epoch: 18 	Training Loss: 0.0034 	Validation Loss: 0.0034 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  19
# Epoch: 19 	Training Loss: 0.0034 	Validation Loss: 0.0034 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  20
# Epoch: 20 	Training Loss: 0.0034 	Validation Loss: 0.0034 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  21
# Epoch: 21 	Training Loss: 0.0034 	Validation Loss: 0.0034 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  22
# Epoch: 22 	Training Loss: 0.0034 	Validation Loss: 0.0034 	Train Accuracy: 0.00 	Validation Accuracy: 0.00
# best model saved for  23
# ...
# Epoch: 117 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43195.88 	Validation Accuracy: 44750.10
# Epoch: 118 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43102.88 	Validation Accuracy: 44088.92
# Epoch: 119 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 43058.18 	Validation Accuracy: 43558.70
# Epoch: 120 	Training Loss: 0.0032 	Validation Loss: 0.0032 	Train Accuracy: 42996.19 	Validation Accuracy: 44233.04
# wandb: Agent Finished Run: scgkgkx2
#
# wandb: Agent Starting Run: j5cgpkdi with config:
# 	activation: ReLU
# 	criterion: MSE
# 	epochs: 120
# 	optimizer: SGD
# wandb: Agent Started Run: j5cgpkdi
# sweep under process
# wandb: WARNING Ignoring project='sweep' passed to wandb.init when running a sweep
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/image_enhancement/uncategorized" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized</a><br/>
#                 Sweep page: <a href="https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized/sweeps/izhsj4p8</a><br/>
# Run page: <a href="https://app.wandb.ai/image_enhancement/uncategorized/runs/j5cgpkdi" target="_blank">https://app.wandb.ai/image_enhancement/uncategorized/runs/j5cgpkdi</a><br/>
# wandb: Wandb version 0.9.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# best model saved for  1
# Epoch: 1 	Training Loss: 0.0028 	Validation Loss: 0.0025 	Train Accuracy: 2513.90 	Validation Accuracy: 2708.94
# Epoch: 2 	Training Loss: 0.0025 	Validation Loss: 0.0026 	Train Accuracy: 3141.03 	Validation Accuracy: 3406.12
# best model saved for  3
# Epoch: 3 	Training Loss: 0.0024 	Validation Loss: 0.0024 	Train Accuracy: 3210.71 	Validation Accuracy: 3077.70
# best model saved for  4
# Epoch: 4 	Training Loss: 0.0024 	Validation Loss: 0.0023 	Train Accuracy: 3162.94 	Validation Accuracy: 3265.56
# Epoch: 5 	Training Loss: 0.0023 	Validation Loss: 0.0024 	Train Accuracy: 3149.86 	Validation Accuracy: 3012.94
# best model saved for  6
# Epoch: 6 	Training Loss: 0.0023 	Validation Loss: 0.0022 	Train Accuracy: 3131.94 	Validation Accuracy: 3077.84
# Epoch: 7 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 3147.28 	Validation Accuracy: 3106.26
# Epoch: 8 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 3122.83 	Validation Accuracy: 3055.98
# best model saved for  9
# Epoch: 9 	Training Loss: 0.0023 	Validation Loss: 0.0021 	Train Accuracy: 3146.87 	Validation Accuracy: 3150.44
# Epoch: 10 	Training Loss: 0.0023 	Validation Loss: 0.0022 	Train Accuracy: 3215.04 	Validation Accuracy: 3365.06
# Epoch: 11 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 3282.60 	Validation Accuracy: 2962.60
# Epoch: 12 	Training Loss: 0.0023 	Validation Loss: 0.0025 	Train Accuracy: 3273.06 	Validation Accuracy: 2789.70
# Epoch: 13 	Training Loss: 0.0022 	Validation Loss: 0.0024 	Train Accuracy: 3260.15 	Validation Accuracy: 3759.44
# best model saved for  14
# Epoch: 14 	Training Loss: 0.0023 	Validation Loss: 0.0020 	Train Accuracy: 3244.01 	Validation Accuracy: 3051.86
# Epoch: 15 	Training Loss: 0.0023 	Validation Loss: 0.0022 	Train Accuracy: 3261.93 	Validation Accuracy: 3632.32
# Epoch: 16 	Training Loss: 0.0023 	Validation Loss: 0.0024 	Train Accuracy: 3258.67 	Validation Accuracy: 4218.04
# Epoch: 17 	Training Loss: 0.0023 	Validation Loss: 0.0022 	Train Accuracy: 3335.90 	Validation Accuracy: 3766.54
# Epoch: 18 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 3377.16 	Validation Accuracy: 4157.28
# Epoch: 19 	Training Loss: 0.0023 	Validation Loss: 0.0022 	Train Accuracy: 3429.58 	Validation Accuracy: 4125.56
# Epoch: 20 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 3535.39 	Validation Accuracy: 4416.08
# Epoch: 21 	Training Loss: 0.0022 	Validation Loss: 0.0023 	Train Accuracy: 3792.73 	Validation Accuracy: 9501.26
# Epoch: 22 	Training Loss: 0.0023 	Validation Loss: 0.0023 	Train Accuracy: 4643.99 	Validation Accuracy: 4976.82
# Epoch: 23 	Training Loss: 0.0022 	Validation Loss: 0.0022 	Train Accuracy: 5746.79 	Validation Accuracy: 8662.64
# best model saved for  24
# Epoch: 24 	Training Loss: 0.0022 	Validation Loss: 0.0020 	Train Accuracy: 8134.36 	Validation Accuracy: 2694.58
# Epoch: 25 	Training Loss: 0.0022 	Validation Loss: 0.0021 	Train Accuracy: 12007.12 	Validation Accuracy: 2706.90
# Epoch: 26 	Training Loss: 0.0022 	Validation Loss: 0.0024 	Train Accuracy: 15552.61 	Validation Accuracy: 2654.72
# Epoch: 27 	Training Loss: 0.0022 	Validation Loss: 0.0020 	Train Accuracy: 17484.05 	Validation Accuracy: 2722.40
# Epoch: 28 	Training Loss: 0.0022 	Validation Loss: 0.0022 	Train Accuracy: 18871.36 	Validation Accuracy: 2689.98
# Epoch: 29 	Training Loss: 0.0022 	Validation Loss: 0.0025 	Train Accuracy: 19508.86 	Validation Accuracy: 2658.66
# Epoch: 30 	Training Loss: 0.0022 	Validation Loss: 0.0022 	Train Accuracy: 20161.46 	Validation Accuracy: 2724.64
# best model saved for  31
# Epoch: 31 	Training Loss: 0.0021 	Validation Loss: 0.0018 	Train Accuracy: 20371.96 	Validation Accuracy: 2713.88
# Epoch: 32 	Training Loss: 0.0021 	Validation Loss: 0.0019 	Train Accuracy: 21054.47 	Validation Accuracy: 2710.14
# Epoch: 33 	Training Loss: 0.0021 	Validation Loss: 0.0022 	Train Accuracy: 21030.35 	Validation Accuracy: 2702.26
# Epoch: 34 	Training Loss: 0.0021 	Validation Loss: 0.0019 	Train Accuracy: 21310.30 	Validation Accuracy: 2733.88
# Epoch: 35 	Training Loss: 0.0020 	Validation Loss: 0.0021 	Train Accuracy: 21133.56 	Validation Accuracy: 2679.92
# best model saved for  36
# Epoch: 36 	Training Loss: 0.0020 	Validation Loss: 0.0018 	Train Accuracy: 21173.26 	Validation Accuracy: 2715.80
# Epoch: 37 	Training Loss: 0.0020 	Validation Loss: 0.0019 	Train Accuracy: 21319.75 	Validation Accuracy: 2673.08
# best model saved for  38
# Epoch: 38 	Training Loss: 0.0019 	Validation Loss: 0.0013 	Train Accuracy: 20980.80 	Validation Accuracy: 3481.28
# Epoch: 39 	Training Loss: 0.0019 	Validation Loss: 0.0019 	Train Accuracy: 21342.64 	Validation Accuracy: 2722.24
# best model saved for  40
# Epoch: 40 	Training Loss: 0.0019 	Validation Loss: 0.0012 	Train Accuracy: 20409.79 	Validation Accuracy: 3642.74
# Epoch: 41 	Training Loss: 0.0019 	Validation Loss: 0.0020 	Train Accuracy: 20104.08 	Validation Accuracy: 42109.16
# Epoch: 42 	Training Loss: 0.0018 	Validation Loss: 0.0022 	Train Accuracy: 19687.25 	Validation Accuracy: 43109.50
# Epoch: 43 	Training Loss: 0.0017 	Validation Loss: 0.0026 	Train Accuracy: 18046.76 	Validation Accuracy: 2317.50
# Epoch: 44 	Training Loss: 0.0017 	Validation Loss: 0.0023 	Train Accuracy: 17058.38 	Validation Accuracy: 43124.76
# Epoch: 45 	Training Loss: 0.0017 	Validation Loss: 0.0024 	Train Accuracy: 18003.16 	Validation Accuracy: 44128.14
# best model saved for  46
# Epoch: 46 	Training Loss: 0.0017 	Validation Loss: 0.0010 	Train Accuracy: 18401.39 	Validation Accuracy: 4319.12
# Epoch: 47 	Training Loss: 0.0018 	Validation Loss: 0.0022 	Train Accuracy: 19799.04 	Validation Accuracy: 43374.24
# Epoch: 48 	Training Loss: 0.0018 	Validation Loss: 0.0021 	Train Accuracy: 21488.63 	Validation Accuracy: 2339.40
# Epoch: 49 	Training Loss: 0.0018 	Validation Loss: 0.0017 	Train Accuracy: 21541.70 	Validation Accuracy: 2673.20
# best model saved for  50
# Epoch: 50 	Training Loss: 0.0018 	Validation Loss: 0.0009 	Train Accuracy: 22265.67 	Validation Accuracy: 4608.48
# Epoch: 51 	Training Loss: 0.0019 	Validation Loss: 0.0016 	Train Accuracy: 24246.62 	Validation Accuracy: 43050.32
# Epoch: 52 	Training Loss: 0.0018 	Validation Loss: 0.0013 	Train Accuracy: 23021.42 	Validation Accuracy: 2686.98
# Epoch: 53 	Training Loss: 0.0019 	Validation Loss: 0.0010 	Train Accuracy: 24355.35 	Validation Accuracy: 2670.36
# Epoch: 54 	Training Loss: 0.0019 	Validation Loss: 0.0010 	Train Accuracy: 25403.18 	Validation Accuracy: 2690.86
# Epoch: 55 	Training Loss: 0.0018 	Validation Loss: 0.0021 	Train Accuracy: 25944.45 	Validation Accuracy: 44414.66
# Epoch: 56 	Training Loss: 0.0019 	Validation Loss: 0.0016 	Train Accuracy: 26523.49 	Validation Accuracy: 43026.26
# Epoch: 57 	Training Loss: 0.0019 	Validation Loss: 0.0023 	Train Accuracy: 26308.97 	Validation Accuracy: 44688.38
# Epoch: 58 	Training Loss: 0.0018 	Validation Loss: 0.0019 	Train Accuracy: 26224.76 	Validation Accuracy: 44336.90
# Epoch: 59 	Training Loss: 0.0018 	Validation Loss: 0.0010 	Train Accuracy: 27143.91 	Validation Accuracy: 41594.24
# Epoch: 60 	Training Loss: 0.0018 	Validation Loss: 0.0016 	Train Accuracy: 26963.81 	Validation Accuracy: 43965.94
# Epoch: 61 	Training Loss: 0.0018 	Validation Loss: 0.0017 	Train Accuracy: 26989.00 	Validation Accuracy: 43282.64
# best model saved for  62
# Epoch: 62 	Training Loss: 0.0017 	Validation Loss: 0.0005 	Train Accuracy: 27615.47 	Validation Accuracy: 21405.64
# Epoch: 63 	Training Loss: 0.0018 	Validation Loss: 0.0012 	Train Accuracy: 27879.97 	Validation Accuracy: 42812.14
# Epoch: 64 	Training Loss: 0.0018 	Validation Loss: 0.0023 	Train Accuracy: 28167.86 	Validation Accuracy: 43828.46
# Epoch: 65 	Training Loss: 0.0017 	Validation Loss: 0.0024 	Train Accuracy: 28343.42 	Validation Accuracy: 44064.80
# Epoch: 66 	Training Loss: 0.0017 	Validation Loss: 0.0006 	Train Accuracy: 28411.93 	Validation Accuracy: 3437.58
# Epoch: 67 	Training Loss: 0.0017 	Validation Loss: 0.0024 	Train Accuracy: 27948.42 	Validation Accuracy: 44287.84
# Epoch: 68 	Training Loss: 0.0017 	Validation Loss: 0.0013 	Train Accuracy: 28468.40 	Validation Accuracy: 42897.84
# Epoch: 69 	Training Loss: 0.0017 	Validation Loss: 0.0030 	Train Accuracy: 28412.88 	Validation Accuracy: 1957.22
# Epoch: 70 	Training Loss: 0.0017 	Validation Loss: 0.0014 	Train Accuracy: 28890.06 	Validation Accuracy: 2334.24
# Epoch: 71 	Training Loss: 0.0016 	Validation Loss: 0.0038 	Train Accuracy: 28559.89 	Validation Accuracy: 1232.02
# Epoch: 72 	Training Loss: 0.0017 	Validation Loss: 0.0007 	Train Accuracy: 28948.62 	Validation Accuracy: 42274.64
# Epoch: 73 	Training Loss: 0.0016 	Validation Loss: 0.0014 	Train Accuracy: 28929.57 	Validation Accuracy: 43682.76
# Epoch: 74 	Training Loss: 0.0016 	Validation Loss: 0.0021 	Train Accuracy: 28845.23 	Validation Accuracy: 2147.36
# Epoch: 75 	Training Loss: 0.0016 	Validation Loss: 0.0013 	Train Accuracy: 28531.70 	Validation Accuracy: 43074.48
# Epoch: 76 	Training Loss: 0.0016 	Validation Loss: 0.0018 	Train Accuracy: 29350.13 	Validation Accuracy: 2345.40
# Epoch: 77 	Training Loss: 0.0016 	Validation Loss: 0.0011 	Train Accuracy: 28745.34 	Validation Accuracy: 42891.12
# Epoch: 78 	Training Loss: 0.0016 	Validation Loss: 0.0023 	Train Accuracy: 28987.12 	Validation Accuracy: 44227.00
# Epoch: 79 	Training Loss: 0.0016 	Validation Loss: 0.0007 	Train Accuracy: 29483.40 	Validation Accuracy: 3719.08
# Epoch: 80 	Training Loss: 0.0016 	Validation Loss: 0.0019 	Train Accuracy: 29491.82 	Validation Accuracy: 43590.46
# Epoch: 81 	Training Loss: 0.0016 	Validation Loss: 0.0008 	Train Accuracy: 29259.84 	Validation Accuracy: 3251.64
# Epoch: 82 	Training Loss: 0.0016 	Validation Loss: 0.0018 	Train Accuracy: 29779.15 	Validation Accuracy: 43784.34
# Epoch: 83 	Training Loss: 0.0015 	Validation Loss: 0.0023 	Train Accuracy: 29764.96 	Validation Accuracy: 43265.88
# Epoch: 84 	Training Loss: 0.0016 	Validation Loss: 0.0021 	Train Accuracy: 29146.68 	Validation Accuracy: 1936.50
# Epoch: 85 	Training Loss: 0.0015 	Validation Loss: 0.0009 	Train Accuracy: 29536.18 	Validation Accuracy: 43809.20
# Epoch: 86 	Training Loss: 0.0015 	Validation Loss: 0.0014 	Train Accuracy: 29829.35 	Validation Accuracy: 44038.58
# Epoch: 87 	Training Loss: 0.0015 	Validation Loss: 0.0030 	Train Accuracy: 29541.79 	Validation Accuracy: 1934.40
# Epoch: 88 	Training Loss: 0.0015 	Validation Loss: 0.0020 	Train Accuracy: 28455.45 	Validation Accuracy: 43463.76
# Epoch: 89 	Training Loss: 0.0015 	Validation Loss: 0.0026 	Train Accuracy: 29238.38 	Validation Accuracy: 1952.86
# Epoch: 90 	Training Loss: 0.0015 	Validation Loss: 0.0011 	Train Accuracy: 28701.02 	Validation Accuracy: 3011.66
# Epoch: 91 	Training Loss: 0.0015 	Validation Loss: 0.0018 	Train Accuracy: 29213.32 	Validation Accuracy: 43597.12
# Epoch: 92 	Training Loss: 0.0015 	Validation Loss: 0.0008 	Train Accuracy: 29610.38 	Validation Accuracy: 43339.28
# Epoch: 93 	Training Loss: 0.0015 	Validation Loss: 0.0017 	Train Accuracy: 29027.83 	Validation Accuracy: 43900.04
# Epoch: 94 	Training Loss: 0.0015 	Validation Loss: 0.0019 	Train Accuracy: 29430.27 	Validation Accuracy: 44822.16
# Epoch: 95 	Training Loss: 0.0015 	Validation Loss: 0.0023 	Train Accuracy: 28917.30 	Validation Accuracy: 1948.34
# Epoch: 96 	Training Loss: 0.0015 	Validation Loss: 0.0019 	Train Accuracy: 29126.86 	Validation Accuracy: 43204.90
# Epoch: 97 	Training Loss: 0.0015 	Validation Loss: 0.0020 	Train Accuracy: 29151.36 	Validation Accuracy: 43895.74
# Epoch: 98 	Training Loss: 0.0015 	Validation Loss: 0.0018 	Train Accuracy: 29137.22 	Validation Accuracy: 43523.48
# best model saved for  99
# Epoch: 99 	Training Loss: 0.0015 	Validation Loss: 0.0004 	Train Accuracy: 28664.55 	Validation Accuracy: 40181.62
# Epoch: 100 	Training Loss: 0.0015 	Validation Loss: 0.0018 	Train Accuracy: 28977.67 	Validation Accuracy: 43017.86
# Epoch: 101 	Training Loss: 0.0015 	Validation Loss: 0.0007 	Train Accuracy: 29020.51 	Validation Accuracy: 43508.62
# Epoch: 102 	Training Loss: 0.0014 	Validation Loss: 0.0015 	Train Accuracy: 28914.04 	Validation Accuracy: 2317.22
# Epoch: 103 	Training Loss: 0.0014 	Validation Loss: 0.0009 	Train Accuracy: 29025.57 	Validation Accuracy: 42824.52
# Epoch: 104 	Training Loss: 0.0014 	Validation Loss: 0.0016 	Train Accuracy: 29434.08 	Validation Accuracy: 2331.74
# Epoch: 105 	Training Loss: 0.0014 	Validation Loss: 0.0005 	Train Accuracy: 29176.00 	Validation Accuracy: 7173.64
# Epoch: 106 	Training Loss: 0.0014 	Validation Loss: 0.0005 	Train Accuracy: 28539.05 	Validation Accuracy: 41631.70
# Epoch: 107 	Training Loss: 0.0014 	Validation Loss: 0.0019 	Train Accuracy: 29070.54 	Validation Accuracy: 44204.90
# Epoch: 108 	Training Loss: 0.0014 	Validation Loss: 0.0020 	Train Accuracy: 28999.87 	Validation Accuracy: 44481.10
# Epoch: 109 	Training Loss: 0.0014 	Validation Loss: 0.0019 	Train Accuracy: 29375.02 	Validation Accuracy: 44127.18
# Epoch: 110 	Training Loss: 0.0014 	Validation Loss: 0.0020 	Train Accuracy: 28681.17 	Validation Accuracy: 44174.86
# Epoch: 111 	Training Loss: 0.0013 	Validation Loss: 0.0016 	Train Accuracy: 28480.64 	Validation Accuracy: 2270.18
# Epoch: 112 	Training Loss: 0.0013 	Validation Loss: 0.0006 	Train Accuracy: 28146.72 	Validation Accuracy: 42071.10
# Epoch: 113 	Training Loss: 0.0013 	Validation Loss: 0.0016 	Train Accuracy: 28661.90 	Validation Accuracy: 43715.80
# Epoch: 114 	Training Loss: 0.0013 	Validation Loss: 0.0023 	Train Accuracy: 28159.25 	Validation Accuracy: 1960.50
# Epoch: 115 	Training Loss: 0.0013 	Validation Loss: 0.0005 	Train Accuracy: 28809.61 	Validation Accuracy: 41616.42
# Epoch: 116 	Training Loss: 0.0013 	Validation Loss: 0.0007 	Train Accuracy: 28700.81 	Validation Accuracy: 43583.12
# Epoch: 117 	Training Loss: 0.0013 	Validation Loss: 0.0005 	Train Accuracy: 28450.04 	Validation Accuracy: 42602.34
# Epoch: 118 	Training Loss: 0.0013 	Validation Loss: 0.0009 	Train Accuracy: 28603.39 	Validation Accuracy: 43449.58
# best model saved for  119
# Epoch: 119 	Training Loss: 0.0013 	Validation Loss: 0.0004 	Train Accuracy: 29089.49 	Validation Accuracy: 41238.46
# Epoch: 120 	Training Loss: 0.0013 	Validation Loss: 0.0019 	Train Accuracy: 28837.12 	Validation Accuracy: 44032.90
# wandb: Agent Finished Run: j5cgpkdi

# %% [markdown]
# ## Quantitative Analysis of the test images

# %%
def psnr(img1,img2):
    """
    to get the psnr values of the images
    """

    img1 = np.asarray(img1)
    img2 = np.asarray(img2)
    maxi = 255 # img1 should be the original img
    mse = np.mean( (img1 - img2) ** 2 )
    if mse == 0:
      return 100
    else:
      return(20*math.log(maxi / math.sqrt(mse)))

def ssim(img1,img2):
    """
    to get the ssim values for the images
    """
    img1 = np.asarray(img1)
    img2 = np.asarray(img2)
    score,diff = compare_ssim(img1,img2,full=True)
    return score

# %% [markdown]
# ## Test on the test data

# %%
# load the best model saved onto the gpu to test the data
model = ConvDenoiser(activation = nn.Tanh())
model.load_state_dict(torch.load('/content/drive/My Drive/Models/Sweep /Activation/MSEAdamtanh.pth', map_location=torch.device('cuda')))
# Out:
# <All keys matched successfully>

# %%
def test(network): 

    """
    This function is used to test the network on the test data by adding a random noise to the images. 
    
    Once the noise is added, we move both the noisy images and the original baseline images to the GPU and then we 
    process the outputs over the network and obtain the predictions. 
    
    The outputs must be such that they must closely resemble the baseline images (without noise) and remove the innate noise in the baseline.
    Then, these images are moved into the CPU for the purpose of visualization of the images in the order, "noisy, enhanced, original".
    """

    count = 0

    for data in test_loader:

        #images = data[0][:]
        images = data[0][:]
        noisy_imgs = data[1][:]
        images = images.float()
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        network = network.to(device)
        # move the input images to gpu for computation
        noisy_imgs = noisy_imgs.to(device)
        images = images.to(device)       
        output = network(images)
        
        # further, move the images and the output to visualize
        output = output.cpu()
        #output = network(images)
        
        images = images.cpu()
        noisy_imgs = noisy_imgs.cpu()
        """
        print(len(data))
        print(noisy_imgs.squeeze(dim=1).shape)
        print(output.squeeze(dim=1).shape)
        print(images.squeeze(dim=1).shape)
        """
        noisy_imgs = noisy_imgs.squeeze(dim=1)
        output = output.squeeze(dim=1)
        images = images.squeeze(dim=1)
        
        
        # use detach when it's an output that requires_grad
        output = output.detach().numpy()        

        img = [images[0], output[0]]
        titles = {1 : "original", 2 : "denoised"}
        plt.figure(figsize=(15,15))
        #print(titles[1])
        for j in range(2):
            plt.subplot(1,2,j+1)
            plt.title(titles[j+1])
            ax = plt.imshow(img[j],cmap='gray')
            ax.axes.xaxis.set_visible(False)
            ax.axes.yaxis.set_visible(False)
        plt.savefig("/content/drive/My Drive/Results/Sweep/Activation/Adam/tanh/original/ORIG_"+str(count)+".png", facecolor='black', bbox_inches = 'tight')
        plt.show()

        count += 1

test(model)
